# %% [markdown]
# # Modeling for predicting the condo size
# ## Neural Network
# In the first part of the modeling, we want to use neural network of fully connected layers. We will try different layers, regularization methods, optimization methods, training rounds.
#
# I made a change to the data, put studio as a seperate category.
# changed 31-50 in age of bnuilding to 45. Changed 0-5 to 2.5, changed 6-10 to 8, changed 11-15 to 13, 16-30 to 23, 31-50 to 45.

# %%
import pandas as pd
import numpy as np

#load the data
df = pd.read_csv('out2.csv',header=0,index_col=0)
tar = pd.read_csv('output.csv',header=0,index_col=0)

#use 1000 dollor as an unit
tar/=1000

# %%
#replace the missing value withe -1
df.fillna(0,inplace=True)
df.isnull().any()
df.dtypes
tar.dtypes
# Out:
# Pricepersqm    float64
# dtype: object

# %%
# set the train set and test set
train=df[:2500]
test=df[2500:]
train_tar=tar[:2500]
test_tar=tar[2500:]

#normalize the training data
mean = train.mean(axis=0)
train -= mean
std = train.std(axis=0)
train /= std

test -= mean
test /= std

#set the validation set
train_par=train[:2100]
train_par_tar=train_tar[:2100]
val=train[2100:]
val_tar=train_tar[2100:]

# %%
from keras import models
from keras import layers

n=train_par.shape[1]
model=models.Sequential()
model.add(layers.Dense(128,activation='relu',input_shape=(n,)))
model.add(layers.Dense(128,activation='relu'))
model.add(layers.Dense(64,activation='relu'))
model.add((layers.Dense(1)))
model.compile(optimizer='rmsprop',loss='mse',metrics=['mae'])

train_par.astype('float64')
train_par_tar.astype('float64')
val.astype('float64')
val_tar.astype('float64')
history=model.fit(train_par,train_par_tar,epochs=50,batch_size=20,validation_data=(val,val_tar),verbose=0)

# %%
#Draw the mse and mae
import matplotlib.pyplot as plt

print(history.history.keys())

dic=history.history
loss=dic['loss']
mae=dic['mae']
val_loss=dic['val_loss']
val_mae=dic['val_mae']
epo=[i for i in range(1,len(loss)+1)]

plt.plot(epo,loss,'ro',label='loss')
plt.plot(epo,val_loss,'b',label='val_loss')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend()
plt.show()
# Out:
# dict_keys(['loss', 'mae', 'val_loss', 'val_mae'])

# %%
plt.plot(epo,mae,'ro',label='mae')
plt.plot(epo,val_mae,'b',label='val_mae')
plt.xlabel('epochs')
plt.ylabel('mae')
plt.legend()
plt.show()

# %%
# we can try another model with fewer nodes and layers
n=train_par.shape[1]
model=models.Sequential()
model.add(layers.Dense(64,activation='relu',input_shape=(n,)))
model.add(layers.Dense(64,activation='relu'))
model.add((layers.Dense(1)))
model.compile(optimizer='rmsprop',loss='mse',metrics=['mae'])


# at this time we can 
history=model.fit(train_par,train_par_tar,epochs=200,batch_size=1,validation_data=(val,val_tar),verbose=0)

# %%
dic=history.history
loss=dic['loss']
mae=dic['mae']
val_loss=dic['val_loss']
val_mae=dic['val_mae']
epo=[i for i in range(1,len(loss)+1)]

plt.plot(epo,loss,'ro',label='loss')
plt.plot(epo,val_loss,'b',label='val_loss')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend()
plt.show()

# %%
plt.plot(epo,mae,'ro',label='mae')
plt.plot(epo,val_mae,'b',label='val_mae')
plt.xlabel('epochs')
plt.ylabel('mae')
plt.legend()
plt.show()

# %%
min(val_mae)
# Out:
# 1.5449751615524292

# %% [markdown]
# It can be seen that the mae value of the validation data set has been rising, indicating that the model is overfitted very quickly. So we add dropout layers into the model.

# %%
# we can try another model with fewer nodes and layers
n=train_par.shape[1]
model=models.Sequential()
model.add(layers.Dense(64,activation='relu',input_shape=(n,)))
model.add(layers.Dropout(0.4))
model.add(layers.Dense(64,activation='relu'))
model.add(layers.Dropout(0.4))
model.add((layers.Dense(1)))
model.compile(optimizer='rmsprop',loss='mse',metrics=['mae'])


# at this time we can 
history=model.fit(train_par,train_par_tar,epochs=150,batch_size=1,validation_data=(val,val_tar),verbose=0)

# %%
dic=history.history
loss=dic['loss']
mae=dic['mae']
val_loss=dic['val_loss']
val_mae=dic['val_mae']
epo=[i for i in range(1,len(loss)+1)]

plt.plot(epo,loss,'ro',label='loss')
plt.plot(epo,val_loss,'b',label='val_loss')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend()
plt.show()

# %%
plt.plot(epo,mae,'ro',label='mae')
plt.plot(epo,val_mae,'b',label='val_mae')
plt.xlabel('epochs')
plt.ylabel('mae')
plt.legend()
plt.show()
min(val_mae)
# Out:
# 1.5020816326141357

# %%
print('the index of smallest mae',val_mae.index(min(val_mae)))
print('the index of smallest mse',val_loss.index(min(val_loss)))
# Out:
# the index of smallest mae 56
# the index of smallest mse 128

# %% [markdown]
# The overfitting was significantly reduced by dropout, the lowest mae occured on the 31 epoch(For different trials this may be different, because the randomness ofoptimization). So, we use all the data from the training set to train the model again.

# %%
model=models.Sequential()
model.add(layers.Dense(64,activation='relu',input_shape=(n,)))
model.add(layers.Dropout(0.4))
model.add(layers.Dense(64,activation='relu'))
model.add(layers.Dropout(0.4))
model.add((layers.Dense(1)))
model.compile(optimizer='rmsprop',loss='mse',metrics=['mae'])
model.fit(train,train_tar,epochs=31,batch_size=1,verbose=0)

result=model.evaluate(test,test_tar)
# Out:
# 13/13 [==============================] - 0s 747us/step - loss: 3.8797 - mae: 1.5046

# %%
result
# Out:
# [3.8797383308410645, 1.5046066045761108]

# %%
print(np.mean(tar))
1.46543/10.305306
# Out:
# Pricepersqm    10.305306
# dtype: float64
# 0.14220150279865537

# %% [markdown]
# From the result, the difference between our predicted price and the actual price is about 1,500 dollars. It is 14.22% of the average house price.
#
# Then we try a smaller network with less neurons.

# %%
# 32 neurons each layers
model=models.Sequential()
model.add(layers.Dense(32,activation='relu',input_shape=(n,)))
model.add(layers.Dropout(0.4))
model.add(layers.Dense(32,activation='relu'))
model.add(layers.Dropout(0.4))
model.add((layers.Dense(1)))
model.compile(optimizer='rmsprop',loss='mse',metrics=['mae'])
history=model.fit(train_par,train_par_tar,epochs=200,batch_size=1,validation_data=(val,val_tar),verbose=0)

dic=history.history
loss=dic['loss']
mae=dic['mae']
val_loss=dic['val_loss']
val_mae=dic['val_mae']
epo=[i for i in range(1,len(loss)+1)]

# draw the mse, also seen as the loss function
plt.plot(epo,loss,'ro',label='loss')
plt.plot(epo,val_loss,'b',label='val_loss')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend()
plt.show()

# draw the mae, also seen as the loss function
plt.plot(epo,mae,'ro',label='mae')
plt.plot(epo,val_mae,'b',label='val_mae')
plt.xlabel('epochs')
plt.ylabel('mae')
plt.legend()
plt.show()

# %%
min(val_mae)
# Out:
# 1.4596003293991089

# %%
# 16 neurons each layers
model=models.Sequential()
model.add(layers.Dense(16,activation='relu',input_shape=(n,)))
model.add(layers.Dropout(0.4))
model.add(layers.Dense(16,activation='relu'))
model.add(layers.Dropout(0.4))
model.add((layers.Dense(1)))
model.compile(optimizer='rmsprop',loss='mse',metrics=['mae'])
history=model.fit(train_par,train_par_tar,epochs=200,batch_size=1,validation_data=(val,val_tar))

dic=history.history
loss=dic['loss']
mae=dic['mae']
val_loss=dic['val_loss']
val_mae=dic['val_mae']
epo=[i for i in range(1,len(loss)+1)]

# draw the mse, also seen as the loss function
plt.plot(epo,loss,'ro',label='loss')
plt.plot(epo,val_loss,'b',label='val_loss')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend()
plt.show()

# draw the mae, also seen as the loss function
plt.plot(epo,mae,'ro',label='mae')
plt.plot(epo,val_mae,'b',label='val_mae')
plt.xlabel('epochs')
plt.ylabel('mae')
plt.legend()
plt.show()
print('the smallest validation mae',min(val_mae))
# Out:
# Epoch 1/200
# 2100/2100 [==============================] - 2s 810us/step - loss: 35.0595 - mae: 4.6930 - val_loss: 12.6840 - val_mae: 2.2160
# Epoch 2/200
# 2100/2100 [==============================] - 2s 826us/step - loss: 18.1821 - mae: 3.3161 - val_loss: 11.2780 - val_mae: 2.0116
# Epoch 3/200
# 2100/2100 [==============================] - 2s 1ms/step - loss: 14.5339 - mae: 2.9640 - val_loss: 10.6872 - val_mae: 1.9140
# Epoch 4/200
# 2100/2100 [==============================] - 2s 916us/step - loss: 12.5731 - mae: 2.6954 - val_loss: 10.1937 - val_mae: 1.8034
# Epoch 5/200
# 2100/2100 [==============================] - 2s 865us/step - loss: 11.4500 - mae: 2.5797 - val_loss: 9.8967 - val_mae: 1.7679
# Epoch 6/200
# 2100/2100 [==============================] - 2s 775us/step - loss: 10.4185 - mae: 2.4850 - val_loss: 10.6405 - val_mae: 1.8854
# Epoch 7/200
# 2100/2100 [==============================] - 2s 755us/step - loss: 9.0840 - mae: 2.3305 - val_loss: 9.5829 - val_mae: 1.7280
# Epoch 8/200
# 2100/2100 [==============================] - 2s 785us/step - loss: 8.3779 - mae: 2.1987 - val_loss: 9.3692 - val_mae: 1.6770
# Epoch 9/200
# 2100/2100 [==============================] - 2s 906us/step - loss: 9.1594 - mae: 2.2708 - val_loss: 9.6586 - val_mae: 1.6918ss: 9.2061 - mae: 2.2
# Epoch 10/200
# 2100/2100 [==============================] - 2s 913us/step - loss: 8.7382 - mae: 2.1762 - val_loss: 9.2769 - val_mae: 1.6373
# Epoch 11/200
# 2100/2100 [==============================] - 2s 923us/step - loss: 7.8215 - mae: 2.1291 - val_loss: 8.8512 - val_mae: 1.6050
# Epoch 12/200
# 2100/2100 [==============================] - 2s 895us/step - loss: 7.7168 - mae: 2.0842 - val_loss: 9.0963 - val_mae: 1.6303
# Epoch 13/200
# 2100/2100 [==============================] - 2s 905us/step - loss: 7.4791 - mae: 2.0135 - val_loss: 9.2559 - val_mae: 1.6484
# Epoch 14/200
# 2100/2100 [==============================] - 2s 864us/step - loss: 7.3834 - mae: 2.0081 - val_loss: 9.0589 - val_mae: 1.6152
# Epoch 15/200
# 2100/2100 [==============================] - 2s 843us/step - loss: 7.3002 - mae: 1.9904 - val_loss: 8.8721 - val_mae: 1.5970
# Epoch 16/200
# 2100/2100 [==============================] - 2s 871us/step - loss: 6.9690 - mae: 1.9779 - val_loss: 8.7250 - val_mae: 1.6017
# Epoch 17/200
# 2100/2100 [==============================] - 2s 903us/step - loss: 6.7074 - mae: 1.9006 - val_loss: 8.7202 - val_mae: 1.5899
# Epoch 18/200
# 2100/2100 [==============================] - 2s 917us/step - loss: 6.6455 - mae: 1.8936 - val_loss: 8.8007 - val_mae: 1.5840
# Epoch 19/200
# 2100/2100 [==============================] - 2s 1ms/step - loss: 6.5727 - mae: 1.8740 - val_loss: 8.9991 - val_mae: 1.6233
# Epoch 20/200
# 2100/2100 [==============================] - 2s 890us/step - loss: 6.2181 - mae: 1.8357 - val_loss: 8.9073 - val_mae: 1.6286
# Epoch 21/200
# 2100/2100 [==============================] - 2s 845us/step - loss: 6.2556 - mae: 1.8589 - val_loss: 8.7659 - val_mae: 1.6251
# Epoch 22/200
# 2100/2100 [==============================] - 2s 853us/step - loss: 6.2789 - mae: 1.8290 - val_loss: 8.7110 - val_mae: 1.6328
# Epoch 23/200
# 2100/2100 [==============================] - 2s 854us/step - loss: 5.8986 - mae: 1.7686 - val_loss: 8.9009 - val_mae: 1.6142
# Epoch 24/200
# 2100/2100 [==============================] - 2s 877us/step - loss: 5.8816 - mae: 1.7586 - val_loss: 8.5974 - val_mae: 1.6143
# Epoch 25/200
# 2100/2100 [==============================] - 2s 890us/step - loss: 6.0988 - mae: 1.8119 - val_loss: 9.2652 - val_mae: 1.6398
# Epoch 26/200
# 2100/2100 [==============================] - 2s 933us/step - loss: 5.8935 - mae: 1.7704 - val_loss: 8.8155 - val_mae: 1.6232
# Epoch 27/200
# 2100/2100 [==============================] - 2s 845us/step - loss: 5.8449 - mae: 1.7843 - val_loss: 8.7586 - val_mae: 1.6125
# Epoch 28/200
# 2100/2100 [==============================] - 2s 902us/step - loss: 5.7256 - mae: 1.7778 - val_loss: 8.8044 - val_mae: 1.6493
# Epoch 29/200
# 2100/2100 [==============================] - 2s 873us/step - loss: 5.8623 - mae: 1.7578 - val_loss: 9.2065 - val_mae: 1.6593
# Epoch 30/200
# 2100/2100 [==============================] - 2s 892us/step - loss: 5.9538 - mae: 1.7795 - val_loss: 9.1559 - val_mae: 1.6559
# Epoch 31/200
# 2100/2100 [==============================] - 2s 862us/step - loss: 5.4544 - mae: 1.7110 - val_loss: 9.0149 - val_mae: 1.6430
# Epoch 32/200
# 2100/2100 [==============================] - 2s 885us/step - loss: 5.5793 - mae: 1.7521 - val_loss: 9.0008 - val_mae: 1.6411
# Epoch 33/200
# 2100/2100 [==============================] - 2s 1ms/step - loss: 5.7348 - mae: 1.7096 - val_loss: 9.1181 - val_mae: 1.6712
# Epoch 34/200
# 2100/2100 [==============================] - 2s 884us/step - loss: 5.6515 - mae: 1.7411 - val_loss: 9.0789 - val_mae: 1.6613
# Epoch 35/200
# 2100/2100 [==============================] - 2s 842us/step - loss: 5.5935 - mae: 1.7173 - val_loss: 8.8649 - val_mae: 1.6577
# Epoch 36/200
# 2100/2100 [==============================] - 2s 815us/step - loss: 5.3959 - mae: 1.7240 - val_loss: 8.8631 - val_mae: 1.6350
# Epoch 37/200
# 2100/2100 [==============================] - 2s 832us/step - loss: 5.6448 - mae: 1.7481 - val_loss: 8.9606 - val_mae: 1.6567
# Epoch 38/200
# 2100/2100 [==============================] - 2s 833us/step - loss: 5.5669 - mae: 1.7132 - val_loss: 8.9425 - val_mae: 1.6661
# Epoch 39/200
# 2100/2100 [==============================] - 2s 843us/step - loss: 5.6955 - mae: 1.7410 - val_loss: 9.1826 - val_mae: 1.6778
# Epoch 40/200
# 2100/2100 [==============================] - 2s 842us/step - loss: 5.3131 - mae: 1.7105 - val_loss: 8.8032 - val_mae: 1.6776
# Epoch 41/200
# 2100/2100 [==============================] - 2s 878us/step - loss: 5.4957 - mae: 1.7317 - val_loss: 8.9328 - val_mae: 1.6572
# Epoch 42/200
# 2100/2100 [==============================] - 2s 865us/step - loss: 5.4183 - mae: 1.7374 - val_loss: 8.6253 - val_mae: 1.6598
# Epoch 43/200
# 2100/2100 [==============================] - 2s 925us/step - loss: 5.5762 - mae: 1.7460 - val_loss: 9.2690 - val_mae: 1.6730
# Epoch 44/200
# 2100/2100 [==============================] - 2s 842us/step - loss: 5.4046 - mae: 1.7123 - val_loss: 9.1090 - val_mae: 1.6716
# Epoch 45/200
# 2100/2100 [==============================] - 2s 868us/step - loss: 5.2188 - mae: 1.6962 - val_loss: 8.8987 - val_mae: 1.6754
# Epoch 46/200
# 2100/2100 [==============================] - 2s 931us/step - loss: 5.3066 - mae: 1.7220 - val_loss: 9.1203 - val_mae: 1.6816
# Epoch 47/200
# 2100/2100 [==============================] - 2s 915us/step - loss: 5.6842 - mae: 1.7496 - val_loss: 8.7193 - val_mae: 1.6608
# Epoch 48/200
# 2100/2100 [==============================] - 2s 928us/step - loss: 5.4169 - mae: 1.7140 - val_loss: 9.2928 - val_mae: 1.6879
# Epoch 49/200
# 2100/2100 [==============================] - 2s 941us/step - loss: 5.4711 - mae: 1.7162 - val_loss: 9.0055 - val_mae: 1.6715
# Epoch 50/200
# 2100/2100 [==============================] - 2s 880us/step - loss: 5.5537 - mae: 1.7324 - val_loss: 9.0539 - val_mae: 1.6816
# Epoch 51/200
# 2100/2100 [==============================] - 2s 879us/step - loss: 5.5922 - mae: 1.7269 - val_loss: 8.8725 - val_mae: 1.6454
# Epoch 52/200
# 2100/2100 [==============================] - 2s 917us/step - loss: 5.3308 - mae: 1.6965 - val_loss: 8.7743 - val_mae: 1.6285
# Epoch 53/200
# 2100/2100 [==============================] - 2s 733us/step - loss: 5.2772 - mae: 1.6794 - val_loss: 9.2107 - val_mae: 1.6570
# Epoch 54/200
# 2100/2100 [==============================] - 1s 697us/step - loss: 5.4013 - mae: 1.7143 - val_loss: 8.7365 - val_mae: 1.6474
# Epoch 55/200
# 2100/2100 [==============================] - 1s 709us/step - loss: 5.7504 - mae: 1.7253 - val_loss: 9.0786 - val_mae: 1.6772
# Epoch 56/200
# 2100/2100 [==============================] - 1s 711us/step - loss: 5.2160 - mae: 1.6856 - val_loss: 9.2613 - val_mae: 1.6945
# Epoch 57/200
# 2100/2100 [==============================] - 2s 714us/step - loss: 5.5173 - mae: 1.7183 - val_loss: 9.1149 - val_mae: 1.6922
# Epoch 58/200
# 2100/2100 [==============================] - 1s 699us/step - loss: 5.1179 - mae: 1.6935 - val_loss: 9.1664 - val_mae: 1.6782
# Epoch 59/200
# 2100/2100 [==============================] - 1s 694us/step - loss: 5.3359 - mae: 1.6987 - val_loss: 9.5955 - val_mae: 1.7171
# Epoch 60/200
# 2100/2100 [==============================] - 2s 716us/step - loss: 5.3166 - mae: 1.6798 - val_loss: 8.7458 - val_mae: 1.6395
# Epoch 61/200
# 2100/2100 [==============================] - 1s 688us/step - loss: 5.4927 - mae: 1.7136 - val_loss: 9.0542 - val_mae: 1.6517
# Epoch 62/200
# 2100/2100 [==============================] - 2s 745us/step - loss: 5.4930 - mae: 1.7262 - val_loss: 8.8320 - val_mae: 1.6630
# Epoch 63/200
# 2100/2100 [==============================] - 2s 1ms/step - loss: 5.3417 - mae: 1.6985 - val_loss: 8.8337 - val_mae: 1.6433
# Epoch 64/200
# 2100/2100 [==============================] - 2s 1ms/step - loss: 5.3716 - mae: 1.7090 - val_loss: 9.0719 - val_mae: 1.6641
# Epoch 65/200
# 2100/2100 [==============================] - 2s 815us/step - loss: 5.4221 - mae: 1.7036 - val_loss: 9.3134 - val_mae: 1.6748
# Epoch 66/200
# 2100/2100 [==============================] - 2s 823us/step - loss: 5.7219 - mae: 1.7145 - val_loss: 9.0700 - val_mae: 1.6808
# Epoch 67/200
# 2100/2100 [==============================] - 2s 837us/step - loss: 5.2976 - mae: 1.6723 - val_loss: 9.1485 - val_mae: 1.6708
# Epoch 68/200
# 2100/2100 [==============================] - 2s 799us/step - loss: 5.3423 - mae: 1.6801 - val_loss: 9.0446 - val_mae: 1.6504
# Epoch 69/200
# 2100/2100 [==============================] - 2s 917us/step - loss: 5.5962 - mae: 1.7117 - val_loss: 9.2548 - val_mae: 1.6908
# Epoch 70/200
# 2100/2100 [==============================] - 2s 966us/step - loss: 5.5367 - mae: 1.6974 - val_loss: 9.0562 - val_mae: 1.6658
# Epoch 71/200
# 2100/2100 [==============================] - 2s 893us/step - loss: 5.2938 - mae: 1.6851 - val_loss: 9.1252 - val_mae: 1.6559
# Epoch 72/200
# 2100/2100 [==============================] - 2s 846us/step - loss: 5.3102 - mae: 1.6881 - val_loss: 8.9440 - val_mae: 1.6715
# Epoch 73/200
# 2100/2100 [==============================] - 2s 828us/step - loss: 5.3881 - mae: 1.7100 - val_loss: 8.9860 - val_mae: 1.6519
# Epoch 74/200
# 2100/2100 [==============================] - 2s 834us/step - loss: 5.3603 - mae: 1.6786 - val_loss: 8.8146 - val_mae: 1.6697
# Epoch 75/200
# 2100/2100 [==============================] - 2s 981us/step - loss: 5.5420 - mae: 1.7114 - val_loss: 8.8173 - val_mae: 1.6601
# Epoch 76/200
# 2100/2100 [==============================] - 2s 870us/step - loss: 5.4547 - mae: 1.6929 - val_loss: 9.2828 - val_mae: 1.7085
# Epoch 77/200
# 2100/2100 [==============================] - 2s 797us/step - loss: 5.3825 - mae: 1.6861 - val_loss: 9.0329 - val_mae: 1.6891
# Epoch 78/200
# 2100/2100 [==============================] - 2s 812us/step - loss: 5.5756 - mae: 1.7211 - val_loss: 9.3192 - val_mae: 1.7017
# Epoch 79/200
# 2100/2100 [==============================] - 2s 864us/step - loss: 5.4621 - mae: 1.7002 - val_loss: 8.8345 - val_mae: 1.6742
# Epoch 80/200
# 2100/2100 [==============================] - 2s 919us/step - loss: 5.5126 - mae: 1.7200 - val_loss: 9.2350 - val_mae: 1.7076
# Epoch 81/200
# 2100/2100 [==============================] - 2s 871us/step - loss: 5.5695 - mae: 1.7210 - val_loss: 9.1731 - val_mae: 1.6860
# Epoch 82/200
# 2100/2100 [==============================] - 2s 854us/step - loss: 5.3557 - mae: 1.6907 - val_loss: 9.3989 - val_mae: 1.6935
# Epoch 83/200
# 2100/2100 [==============================] - 2s 875us/step - loss: 5.5033 - mae: 1.7249 - val_loss: 9.0880 - val_mae: 1.6775
# Epoch 84/200
# 2100/2100 [==============================] - 2s 895us/step - loss: 5.6865 - mae: 1.7259 - val_loss: 9.2898 - val_mae: 1.7030
# Epoch 85/200
# 2100/2100 [==============================] - 2s 888us/step - loss: 5.3681 - mae: 1.6908 - val_loss: 9.2502 - val_mae: 1.6900
# Epoch 86/200
# 2100/2100 [==============================] - 2s 886us/step - loss: 5.0858 - mae: 1.6898 - val_loss: 9.3712 - val_mae: 1.6721
# Epoch 87/200
# 2100/2100 [==============================] - 2s 887us/step - loss: 5.5150 - mae: 1.7089 - val_loss: 9.9103 - val_mae: 1.7382
# Epoch 88/200
# 2100/2100 [==============================] - 2s 966us/step - loss: 5.4544 - mae: 1.7069 - val_loss: 8.8657 - val_mae: 1.6539
# Epoch 89/200
# 2100/2100 [==============================] - 2s 904us/step - loss: 5.4181 - mae: 1.7136 - val_loss: 9.3277 - val_mae: 1.6981
# Epoch 90/200
# 2100/2100 [==============================] - 2s 907us/step - loss: 5.1373 - mae: 1.6837 - val_loss: 8.8988 - val_mae: 1.6746
# Epoch 91/200
# 2100/2100 [==============================] - 2s 893us/step - loss: 5.5420 - mae: 1.6954 - val_loss: 9.1592 - val_mae: 1.6997
# Epoch 92/200
# 2100/2100 [==============================] - 2s 893us/step - loss: 5.5393 - mae: 1.7137 - val_loss: 9.3965 - val_mae: 1.6822
# Epoch 93/200
# 2100/2100 [==============================] - 2s 902us/step - loss: 5.0958 - mae: 1.6847 - val_loss: 9.3615 - val_mae: 1.6898
# Epoch 94/200
# 2100/2100 [==============================] - 2s 932us/step - loss: 5.2716 - mae: 1.6657 - val_loss: 9.2153 - val_mae: 1.6655
# Epoch 95/200
# 2100/2100 [==============================] - 2s 905us/step - loss: 5.5450 - mae: 1.7234 - val_loss: 9.0244 - val_mae: 1.6751
# Epoch 96/200
# 2100/2100 [==============================] - 2s 928us/step - loss: 5.1070 - mae: 1.6691 - val_loss: 8.9137 - val_mae: 1.6783
# Epoch 97/200
# 2100/2100 [==============================] - 2s 916us/step - loss: 5.5318 - mae: 1.6962 - val_loss: 9.4028 - val_mae: 1.6992
# Epoch 98/200
# 2100/2100 [==============================] - 2s 896us/step - loss: 5.1494 - mae: 1.6823 - val_loss: 8.9648 - val_mae: 1.6677
# Epoch 99/200
# 2100/2100 [==============================] - 2s 893us/step - loss: 5.3003 - mae: 1.6803 - val_loss: 9.5134 - val_mae: 1.6980
# Epoch 100/200
# 2100/2100 [==============================] - 2s 929us/step - loss: 5.2360 - mae: 1.6890 - val_loss: 9.6358 - val_mae: 1.7113
# Epoch 101/200
# 2100/2100 [==============================] - 2s 905us/step - loss: 5.0834 - mae: 1.6805 - val_loss: 9.1985 - val_mae: 1.6697
# Epoch 102/200
# 2100/2100 [==============================] - 2s 962us/step - loss: 5.1195 - mae: 1.6766 - val_loss: 8.7442 - val_mae: 1.6451
# Epoch 103/200
# 2100/2100 [==============================] - 2s 835us/step - loss: 5.0293 - mae: 1.6745 - val_loss: 8.8592 - val_mae: 1.6670
# Epoch 104/200
# 2100/2100 [==============================] - 2s 872us/step - loss: 5.4183 - mae: 1.7302 - val_loss: 8.8941 - val_mae: 1.6599
# Epoch 105/200
# 2100/2100 [==============================] - 2s 960us/step - loss: 5.3559 - mae: 1.6949 - val_loss: 9.0573 - val_mae: 1.6696
# Epoch 106/200
# 2100/2100 [==============================] - 2s 914us/step - loss: 5.3547 - mae: 1.7000 - val_loss: 8.8093 - val_mae: 1.6581
# Epoch 107/200
# 2100/2100 [==============================] - 2s 821us/step - loss: 5.2633 - mae: 1.6859 - val_loss: 9.0728 - val_mae: 1.6632
# Epoch 108/200
# 2100/2100 [==============================] - 2s 859us/step - loss: 5.3867 - mae: 1.7037 - val_loss: 8.9407 - val_mae: 1.6587
# Epoch 109/200
# 2100/2100 [==============================] - 2s 856us/step - loss: 5.6789 - mae: 1.7158 - val_loss: 8.9485 - val_mae: 1.6613
# Epoch 110/200
# 2100/2100 [==============================] - 2s 859us/step - loss: 5.2034 - mae: 1.6842 - val_loss: 9.1018 - val_mae: 1.7054
# Epoch 111/200
# 2100/2100 [==============================] - 2s 885us/step - loss: 5.4300 - mae: 1.6719 - val_loss: 9.3111 - val_mae: 1.6494
# Epoch 112/200
# 2100/2100 [==============================] - 2s 887us/step - loss: 5.4121 - mae: 1.6839 - val_loss: 9.0428 - val_mae: 1.7102
# Epoch 113/200
# 2100/2100 [==============================] - 2s 923us/step - loss: 5.2906 - mae: 1.6782 - val_loss: 8.9352 - val_mae: 1.6697
# Epoch 114/200
# 2100/2100 [==============================] - 2s 943us/step - loss: 5.2908 - mae: 1.7029 - val_loss: 9.2638 - val_mae: 1.6962
# Epoch 115/200
# 2100/2100 [==============================] - 2s 918us/step - loss: 5.4663 - mae: 1.7040 - val_loss: 8.9090 - val_mae: 1.6635
# Epoch 116/200
# 2100/2100 [==============================] - 2s 922us/step - loss: 5.3825 - mae: 1.6839 - val_loss: 8.9524 - val_mae: 1.7031
# Epoch 117/200
# 2100/2100 [==============================] - 2s 913us/step - loss: 5.0678 - mae: 1.6914 - val_loss: 8.8808 - val_mae: 1.7078
# Epoch 118/200
# 2100/2100 [==============================] - 2s 936us/step - loss: 5.3078 - mae: 1.6807 - val_loss: 9.3639 - val_mae: 1.7025
# Epoch 119/200
# 2100/2100 [==============================] - 2s 782us/step - loss: 5.4349 - mae: 1.6882 - val_loss: 8.9190 - val_mae: 1.6739
# Epoch 120/200
# 2100/2100 [==============================] - 2s 839us/step - loss: 5.5121 - mae: 1.7322 - val_loss: 8.7770 - val_mae: 1.6691
# Epoch 121/200
# 2100/2100 [==============================] - 2s 835us/step - loss: 5.3597 - mae: 1.6642 - val_loss: 8.8970 - val_mae: 1.6850
# Epoch 122/200
# 2100/2100 [==============================] - 2s 935us/step - loss: 5.0251 - mae: 1.6730 - val_loss: 9.7102 - val_mae: 1.7405
# Epoch 123/200
# 2100/2100 [==============================] - 2s 846us/step - loss: 5.1524 - mae: 1.6672 - val_loss: 9.1907 - val_mae: 1.6864
# Epoch 124/200
# 2100/2100 [==============================] - 2s 860us/step - loss: 5.1903 - mae: 1.6821 - val_loss: 9.2734 - val_mae: 1.7055
# Epoch 125/200
# 2100/2100 [==============================] - 2s 1ms/step - loss: 4.8434 - mae: 1.6501 - val_loss: 8.8121 - val_mae: 1.6557
# Epoch 126/200
# 2100/2100 [==============================] - 2s 985us/step - loss: 5.1729 - mae: 1.6978 - val_loss: 9.2685 - val_mae: 1.6944
# Epoch 127/200
# 2100/2100 [==============================] - 2s 996us/step - loss: 4.9417 - mae: 1.6558 - val_loss: 8.8440 - val_mae: 1.7052
# Epoch 128/200
# 2100/2100 [==============================] - 2s 863us/step - loss: 5.2083 - mae: 1.6859 - val_loss: 8.6770 - val_mae: 1.6434
# Epoch 129/200
# 2100/2100 [==============================] - 2s 888us/step - loss: 5.1204 - mae: 1.6703 - val_loss: 8.7642 - val_mae: 1.6812
# Epoch 130/200
# 2100/2100 [==============================] - 2s 894us/step - loss: 5.3195 - mae: 1.7006 - val_loss: 8.8644 - val_mae: 1.6863
# Epoch 131/200
# 2100/2100 [==============================] - 2s 872us/step - loss: 5.1298 - mae: 1.6728 - val_loss: 8.9720 - val_mae: 1.7255
# Epoch 132/200
# 2100/2100 [==============================] - 2s 857us/step - loss: 5.2063 - mae: 1.6897 - val_loss: 9.4094 - val_mae: 1.7094
# Epoch 133/200
# 2100/2100 [==============================] - 2s 840us/step - loss: 5.4997 - mae: 1.6949 - val_loss: 9.2238 - val_mae: 1.7284
# Epoch 134/200
# 2100/2100 [==============================] - 2s 869us/step - loss: 5.4630 - mae: 1.7186 - val_loss: 9.3227 - val_mae: 1.7258
# Epoch 135/200
# 2100/2100 [==============================] - 2s 939us/step - loss: 5.3669 - mae: 1.7037 - val_loss: 9.2090 - val_mae: 1.7313.4281 - mae: 1.7
# Epoch 136/200
# 2100/2100 [==============================] - 2s 1ms/step - loss: 5.3060 - mae: 1.6786 - val_loss: 8.6729 - val_mae: 1.6365
# Epoch 137/200
# 2100/2100 [==============================] - 2s 841us/step - loss: 5.7086 - mae: 1.7189 - val_loss: 8.9229 - val_mae: 1.7295
# Epoch 138/200
# 2100/2100 [==============================] - 2s 981us/step - loss: 5.1667 - mae: 1.6888 - val_loss: 9.0549 - val_mae: 1.7122
# Epoch 139/200
# 2100/2100 [==============================] - 2s 1ms/step - loss: 5.0833 - mae: 1.6607 - val_loss: 9.8325 - val_mae: 1.7558
# Epoch 140/200
# 2100/2100 [==============================] - 2s 847us/step - loss: 5.2490 - mae: 1.6913 - val_loss: 9.4923 - val_mae: 1.7567
# Epoch 141/200
# 2100/2100 [==============================] - 2s 819us/step - loss: 5.2537 - mae: 1.6730 - val_loss: 9.3328 - val_mae: 1.7025
# Epoch 142/200
# 2100/2100 [==============================] - 2s 849us/step - loss: 4.7977 - mae: 1.6514 - val_loss: 8.9467 - val_mae: 1.6709
# Epoch 143/200
# 2100/2100 [==============================] - 2s 836us/step - loss: 5.6425 - mae: 1.7101 - val_loss: 8.8429 - val_mae: 1.6729
# Epoch 144/200
# 2100/2100 [==============================] - 2s 853us/step - loss: 5.1790 - mae: 1.6674 - val_loss: 8.7641 - val_mae: 1.6753
# Epoch 145/200
# 2100/2100 [==============================] - 2s 855us/step - loss: 5.3399 - mae: 1.6921 - val_loss: 8.9712 - val_mae: 1.6804
# Epoch 146/200
# 2100/2100 [==============================] - 2s 857us/step - loss: 5.3796 - mae: 1.7259 - val_loss: 8.7617 - val_mae: 1.6797
# Epoch 147/200
# 2100/2100 [==============================] - 2s 919us/step - loss: 5.2533 - mae: 1.7124 - val_loss: 8.9222 - val_mae: 1.6915
# Epoch 148/200
# 2100/2100 [==============================] - 2s 919us/step - loss: 5.3641 - mae: 1.6739 - val_loss: 8.8181 - val_mae: 1.6920
# Epoch 149/200
# 2100/2100 [==============================] - 2s 901us/step - loss: 5.2400 - mae: 1.6767 - val_loss: 8.9833 - val_mae: 1.6810
# Epoch 150/200
# 2100/2100 [==============================] - 2s 911us/step - loss: 5.2105 - mae: 1.6757 - val_loss: 9.2560 - val_mae: 1.7058
# Epoch 151/200
# 2100/2100 [==============================] - 2s 899us/step - loss: 5.2871 - mae: 1.7024 - val_loss: 9.0727 - val_mae: 1.6663
# Epoch 152/200
# 2100/2100 [==============================] - 2s 894us/step - loss: 5.3992 - mae: 1.6881 - val_loss: 8.9777 - val_mae: 1.7049
# Epoch 153/200
# 2100/2100 [==============================] - 2s 909us/step - loss: 5.3424 - mae: 1.6982 - val_loss: 9.0372 - val_mae: 1.7061
# Epoch 154/200
# 2100/2100 [==============================] - 2s 910us/step - loss: 5.0946 - mae: 1.6661 - val_loss: 8.8456 - val_mae: 1.7293
# Epoch 155/200
# 2100/2100 [==============================] - 2s 907us/step - loss: 4.9646 - mae: 1.6621 - val_loss: 8.6590 - val_mae: 1.6539
# Epoch 156/200
# 2100/2100 [==============================] - 2s 969us/step - loss: 5.2809 - mae: 1.6781 - val_loss: 8.9672 - val_mae: 1.6750
# Epoch 157/200
# 2100/2100 [==============================] - 2s 907us/step - loss: 4.9881 - mae: 1.6744 - val_loss: 8.8184 - val_mae: 1.6210
# Epoch 158/200
# 2100/2100 [==============================] - 2s 928us/step - loss: 5.3893 - mae: 1.7234 - val_loss: 9.0682 - val_mae: 1.7341
# Epoch 159/200
# 2100/2100 [==============================] - 2s 934us/step - loss: 4.9633 - mae: 1.6500 - val_loss: 9.0292 - val_mae: 1.6763
# Epoch 160/200
# 2100/2100 [==============================] - 2s 921us/step - loss: 5.3891 - mae: 1.7054 - val_loss: 8.6408 - val_mae: 1.6806
# Epoch 161/200
# 2100/2100 [==============================] - 2s 946us/step - loss: 5.2038 - mae: 1.6893 - val_loss: 9.1683 - val_mae: 1.7266
# Epoch 162/200
# 2100/2100 [==============================] - 2s 915us/step - loss: 5.1191 - mae: 1.6775 - val_loss: 9.1088 - val_mae: 1.7168
# Epoch 163/200
# 2100/2100 [==============================] - 2s 918us/step - loss: 5.0470 - mae: 1.6761 - val_loss: 8.6098 - val_mae: 1.6315
# Epoch 164/200
# 2100/2100 [==============================] - 2s 982us/step - loss: 5.3222 - mae: 1.7031 - val_loss: 8.4919 - val_mae: 1.6654
# Epoch 165/200
# 2100/2100 [==============================] - 2s 911us/step - loss: 5.5364 - mae: 1.6735 - val_loss: 8.8536 - val_mae: 1.6369
# Epoch 166/200
# 2100/2100 [==============================] - 2s 910us/step - loss: 5.2964 - mae: 1.7035 - val_loss: 8.6273 - val_mae: 1.6704
# Epoch 167/200
# 2100/2100 [==============================] - 2s 915us/step - loss: 5.2853 - mae: 1.6854 - val_loss: 9.1155 - val_mae: 1.7069
# Epoch 168/200
# 2100/2100 [==============================] - 2s 910us/step - loss: 5.5990 - mae: 1.7465 - val_loss: 8.9786 - val_mae: 1.7295
# Epoch 169/200
# 2100/2100 [==============================] - 2s 939us/step - loss: 5.4537 - mae: 1.6925 - val_loss: 8.7289 - val_mae: 1.6873
# Epoch 170/200
# 2100/2100 [==============================] - 2s 938us/step - loss: 5.6402 - mae: 1.6973 - val_loss: 8.7112 - val_mae: 1.6884
# Epoch 171/200
# 2100/2100 [==============================] - 2s 931us/step - loss: 5.1744 - mae: 1.6740 - val_loss: 8.4629 - val_mae: 1.6520
# Epoch 172/200
# 2100/2100 [==============================] - 2s 1ms/step - loss: 5.2326 - mae: 1.6905 - val_loss: 8.7203 - val_mae: 1.7107
# Epoch 173/200
# 2100/2100 [==============================] - 2s 956us/step - loss: 5.0890 - mae: 1.6565 - val_loss: 8.9926 - val_mae: 1.7404
# Epoch 174/200
# 2100/2100 [==============================] - 2s 938us/step - loss: 5.3715 - mae: 1.6884 - val_loss: 8.9546 - val_mae: 1.6864
# Epoch 175/200
# 2100/2100 [==============================] - 2s 927us/step - loss: 5.4684 - mae: 1.6919 - val_loss: 8.5320 - val_mae: 1.6526
# Epoch 176/200
# 2100/2100 [==============================] - 2s 910us/step - loss: 5.2972 - mae: 1.6629 - val_loss: 9.0585 - val_mae: 1.6959
# Epoch 177/200
# 2100/2100 [==============================] - 2s 910us/step - loss: 5.3781 - mae: 1.6895 - val_loss: 9.2654 - val_mae: 1.7101
# Epoch 178/200
# 2100/2100 [==============================] - 2s 814us/step - loss: 5.3321 - mae: 1.6991 - val_loss: 9.2349 - val_mae: 1.7655
# Epoch 179/200
# 2100/2100 [==============================] - 2s 875us/step - loss: 5.3948 - mae: 1.7030 - val_loss: 8.8304 - val_mae: 1.7506
# Epoch 180/200
# 2100/2100 [==============================] - 2s 880us/step - loss: 5.3912 - mae: 1.6828 - val_loss: 8.5233 - val_mae: 1.6721
# Epoch 181/200
# 2100/2100 [==============================] - 2s 915us/step - loss: 5.3561 - mae: 1.7128 - val_loss: 8.7924 - val_mae: 1.7152
# Epoch 182/200
# 2100/2100 [==============================] - 2s 870us/step - loss: 5.1693 - mae: 1.6910 - val_loss: 8.8421 - val_mae: 1.7184
# Epoch 183/200
# 2100/2100 [==============================] - 2s 864us/step - loss: 5.2784 - mae: 1.7037 - val_loss: 8.6497 - val_mae: 1.6429
# Epoch 184/200
# 2100/2100 [==============================] - 2s 847us/step - loss: 5.5906 - mae: 1.6856 - val_loss: 8.8346 - val_mae: 1.7154
# Epoch 185/200
# 2100/2100 [==============================] - 2s 855us/step - loss: 5.1815 - mae: 1.7007 - val_loss: 8.9275 - val_mae: 1.7250
# Epoch 186/200
# 2100/2100 [==============================] - 2s 865us/step - loss: 5.3125 - mae: 1.6926 - val_loss: 9.0006 - val_mae: 1.6947
# Epoch 187/200
# 2100/2100 [==============================] - 2s 866us/step - loss: 5.0648 - mae: 1.6677 - val_loss: 8.8225 - val_mae: 1.7071
# Epoch 188/200
# 2100/2100 [==============================] - 2s 871us/step - loss: 5.3691 - mae: 1.6902 - val_loss: 8.9075 - val_mae: 1.6817
# Epoch 189/200
# 2100/2100 [==============================] - 2s 936us/step - loss: 5.4523 - mae: 1.6927 - val_loss: 8.9292 - val_mae: 1.7325
# Epoch 190/200
# 2100/2100 [==============================] - 2s 854us/step - loss: 5.3671 - mae: 1.6970 - val_loss: 8.9055 - val_mae: 1.7088
# Epoch 191/200
# 2100/2100 [==============================] - 2s 871us/step - loss: 5.3822 - mae: 1.7027 - val_loss: 8.9432 - val_mae: 1.6863
# Epoch 192/200
# 2100/2100 [==============================] - 2s 870us/step - loss: 5.0056 - mae: 1.6769 - val_loss: 8.6172 - val_mae: 1.6732
# Epoch 193/200
# 2100/2100 [==============================] - 2s 872us/step - loss: 5.2408 - mae: 1.6795 - val_loss: 8.9048 - val_mae: 1.6554
# Epoch 194/200
# 2100/2100 [==============================] - 2s 896us/step - loss: 5.3268 - mae: 1.6828 - val_loss: 8.5918 - val_mae: 1.6407
# Epoch 195/200
# 2100/2100 [==============================] - 2s 878us/step - loss: 5.0611 - mae: 1.6657 - val_loss: 8.7297 - val_mae: 1.6937
# Epoch 196/200
# 2100/2100 [==============================] - 2s 868us/step - loss: 5.5582 - mae: 1.6988 - val_loss: 9.2084 - val_mae: 1.7584
# Epoch 197/200
# 2100/2100 [==============================] - 2s 850us/step - loss: 5.6881 - mae: 1.7025 - val_loss: 8.8188 - val_mae: 1.7164
# Epoch 198/200
# 2100/2100 [==============================] - 2s 942us/step - loss: 5.5743 - mae: 1.7102 - val_loss: 8.2971 - val_mae: 1.6305
# Epoch 199/200
# 2100/2100 [==============================] - 2s 836us/step - loss: 5.2683 - mae: 1.6866 - val_loss: 8.6369 - val_mae: 1.6539
# Epoch 200/200
# 2100/2100 [==============================] - 2s 859us/step - loss: 5.3936 - mae: 1.7015 - val_loss: 8.7324 - val_mae: 1.6797
# the smallest validation mae 1.5839829444885254

# %%
# 8 neurons each layers
model=models.Sequential()
model.add(layers.Dense(8,activation='relu',input_shape=(n,)))
model.add(layers.Dropout(0.4))
model.add(layers.Dense(8,activation='relu'))
model.add(layers.Dropout(0.4))
model.add((layers.Dense(1)))
model.compile(optimizer='rmsprop',loss='mse',metrics=['mae'])
history=model.fit(train_par,train_par_tar,epochs=200,batch_size=1,validation_data=(val,val_tar),verbose=0)

dic=history.history
loss=dic['loss']
mae=dic['mae']
val_loss=dic['val_loss']
val_mae=dic['val_mae']
epo=[i for i in range(1,len(loss)+1)]

# draw the mse, also seen as the loss function
plt.plot(epo,loss,'ro',label='loss')
plt.plot(epo,val_loss,'b',label='val_loss')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend()
plt.show()

# draw the mae, also seen as the loss function
plt.plot(epo,mae,'ro',label='mae')
plt.plot(epo,val_mae,'b',label='val_mae')
plt.xlabel('epochs')
plt.ylabel('mae')
plt.legend()
plt.show()
print('the smallest validation mae',min(val_mae))
# Out:
# the smallest validation mae 1.786924123764038
